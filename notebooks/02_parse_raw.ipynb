# %% [markdown]
# # 02_parse_raw.ipynb

# %% [markdown]
# ## 1. Objective
# Exploratory notebook to inspect the raw Google Shopping JSON and design the staging schema.
#
# **Goals**
#
# - Pull a small sample from `raycon.raw_google_shopping`
# - Understand the structure of `response_json` (top-level sections and nested lists)
# - Draft the structure of staging tables (`stg_google_shopping_searches`, `stg_google_shopping_results`)
# - This notebook is **read-only** against the database (no writes).

# %% [markdown]
# ## 2. Setup and Configuration

# %% [markdown]
# ### 2.1 Imports

# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option('future.no_silent_downcasting', True)
import json

from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv

# %% [markdown]
# ### 2.2 Connect to Database

# %%
load_dotenv()

user = os.getenv('PGUSER')
password = os.getenv('PGPASSWORD')
pghost = os.getenv('PGHOST')
pgport = os.getenv('PGPORT')
pgdatabase = os.getenv('PGDATABASE')

engine = create_engine(
    f'postgresql+psycopg2://{user}:{password}@{pghost}:{pgport}/{pgdatabase}')

# Verify integrity of connection
pd.read_sql("SELECT * FROM raycon.raw_google_shopping ORDER BY id DESC LIMIT 3", engine)
# Out:
#    id                        pulled_at               keyword  page  \
# 0  28 2025-12-07 17:38:27.301076+00:00  bluetooth headphones     1
# 1  27 2025-12-07 17:38:25.948828+00:00      wireless earbuds     1
# 2  26 2025-12-07 17:38:21.419518+00:00   wireless headphones     1
#
#                                        response_json
# 0  {'filters': [{'type': 'Refine results', 'optio...
# 1  {'filters': [{'type': 'Refine results', 'optio...
# 2  {'filters': [{'type': 'Refine results', 'optio...

# %% [markdown]
# ## 3. Pull Sample Rows
# Grab a small sample of the most recent raw rows so we can inspect the
# `response_json` structure.

# %%
# One row = one SerpAPI call for a given keyword + page.
query = '''
SELECT id, pulled_at, keyword, page, response_json
FROM raycon.raw_google_shopping
ORDER BY pulled_at DESC
LIMIT 7;
'''

with engine.connect() as conn:
    df_raw = pd.read_sql(query, conn)

# %%
df_raw
# Out:
#    id                        pulled_at               keyword  page  \
# 0  28 2025-12-07 17:38:27.301076+00:00  bluetooth headphones     1
# 1  27 2025-12-07 17:38:25.948828+00:00      wireless earbuds     1
# 2  26 2025-12-07 17:38:21.419518+00:00   wireless headphones     1
# 3  25 2025-12-07 17:38:19.396786+00:00          best earbuds     1
# 4  24 2025-12-07 17:38:13.449511+00:00       best headphones     1
# 5  23 2025-12-07 17:38:03.100111+00:00               earbuds     1
# 6  22 2025-12-07 17:38:00.951027+00:00            headphones     1
#
#                                        response_json
# 0  {'filters': [{'type': 'Refine results', 'optio...
# 1  {'filters': [{'type': 'Refine results', 'optio...
# 2  {'filters': [{'type': 'Refine results', 'optio...
# 3  {'filters': [{'type': 'Refine results', 'optio...
# 4  {'filters': [{'type': 'Refine results', 'optio...
# 5  {'filters': [{'type': 'Refine results', 'optio...
# 6  {'filters': [{'type': 'Refine results', 'optio...

# %% [markdown]
# ## 4. Inspect JSON
# Take one `response_json` payload from the sample and inspect:
# - Top-level keys (major sections of the API response)
# - Truncated view of the full nested structure
#
# This helps decide which parts deserve staging tables and which parts are to be left out.

# %% [markdown]
# ### 4.1 Extract one JSON Response

# %%
sample = df_raw.loc[5, :]
id, pulled_at, keyword, page = sample.loc[['id', 'pulled_at', 'keyword', 'page']]

# %%
sample = sample.loc['response_json']
list(sample.keys())
# Out:
# ['filters',
#  'search_metadata',
#  'shopping_results',
#  'search_parameters',
#  'search_information',
#  'serpapi_pagination',
#  'categorized_shopping_results']

# %% [markdown]
# ### 4.2 Preview for Each Key

# %%
# Loop through each top-level key and preview the structure of its value
for key in sample.keys():
    print(f"======== {key} ========")
    try:
        # Print only the first part of each key’s value
        print(json.dumps(sample[key], indent=2)[:5000])
    except TypeError:
        print(sample[key])
    print("\n\n\n\n")
# Out:
# ======== filters ========
# [
#   {
#     "type": "Refine results",
#     "options": [
#       {
#         "text": "On sale",
#         "shoprs": "CAESBEoCGAEYBioHZWFyYnVkczITCAYSB09uIHNhbGUYAiIESgIYAViD6CBgAg",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=earbuds+sale&shoprs=CAESBEoCGAEYBioHZWFyYnVkczITCAYSB09uIHNhbGUYAiIESgIYAViD6CBgAg"
#       },
#       {
#         "text": "Nearby",
#         "shoprs": "CAEYAyoHZWFyYnVkczIMCAMSBk5lYXJieRgCWIPoIGAC",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=earbuds+nearby&shoprs=CAEYAyoHZWFyYnVkczIMCAMSBk5lYXJieRgCWIPoIGAC"
#       },
#       {
#         "text": "Get it tomorrow",
#         "shoprs": "CAESDZoBCgoIEAE4AUABSAEYFCoHZWFyYnVkczIoCBQSD0dldCBpdCB0b21vcnJvdyINmgEKCggQATgBQAFIASoEEAEYAWAC",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=earbuds&shoprs=CAESDZoBCgoIEAE4AUABSAEYFCoHZWFyYnVkczIoCBQSD0dldCBpdCB0b21vcnJvdyINmgEKCggQATgBQAFIASoEEAEYAWAC"
#       },
#       {
#         "text": "New",
#         "shoprs": "CAEYCioHZWFyYnVkczIHCAoSA05ld1iD6CBgAg",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=new+earbuds&shoprs=CAEYCioHZWFyYnVkczIHCAoSA05ld1iD6CBgAg"
#       }
#     ],
#     "input_type": "link_with_icon"
#   },
#   {
#     "type": "Connectivity",
#     "options": [
#       {
#         "text": "Wireless",
#         "shoprs": "CAEYASoHZWFyYnVkczIYCAESCFdpcmVsZXNzOgoIqZo7EKuaOzAAWIPoIGAC",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=wireless+earbuds&shoprs=CAEYASoHZWFyYnVkczIYCAESCFdpcmVsZXNzOgoIqZo7EKuaOzAAWIPoIGAC"
#       },
#       {
#         "text": "Wired",
#         "shoprs": "CAEYASoHZWFyYnVkczIVCAESBVdpcmVkOgoIqZo7EKqaOzAAWIPoIGAC",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=wired+earbuds&shoprs=CAEYASoHZWFyYnVkczIVCAESBVdpcmVkOgoIqZo7EKqaOzAAWIPoIGAC"
#       }
#     ],
#     "input_type": "checkbox"
#   },
#   {
#     "type": "Product Rating",
#     "options": [
#       {
#         "text": "4 and up",
#         "shoprs": "CAESBWIDCJADGB4qB2VhcmJ1ZHMyFQgeEgg0IGFuZCB1cCIFYgMIkANABGAC",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=earbuds&shoprs=CAESBWIDCJADGB4qB2VhcmJ1ZHMyFQgeEgg0IGFuZCB1cCIFYgMIkANABGAC"
#       }
#     ],
#     "input_type": "link"
#   },
#   {
#     "type": "Features",
#     "options": [
#       {
#         "text": "Noise Canceling",
#         "shoprs": "CAEYASoHZWFyYnVkczIfCAESD05vaXNlIENhbmNlbGluZzoKCO3rOhDu6zowA1iD6CBgAg",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=noise+canceling+earbuds&shoprs=CAEYASoHZWFyYnVkczIfCAESD05vaXNlIENhbmNlbGluZzoKCO3rOhDu6zowA1iD6CBgAg"
#       },
#       {
#         "text": "With Microphone",
#         "shoprs": "CAEYASoHZWFyYnVkczIhCAESD1dpdGggTWljcm9waG9uZRgCOgoIsMI-ELHCPjADWIPoIGAC",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=earbuds+with+microphone&shoprs=CAEYASoHZWFyYnVkczIhCAESD1dpdGggTWljcm9waG9uZRgCOgoIsMI-ELHCPjADWIPoIGAC"
#       },
#       {
#         "text": "For Gaming",
#         "shoprs": "CAEYASoHZWFyYnVkczIcCAESCkZvciBHYW1pbmcYAjoKCKmjPhCqoz4wA1iD6CBgAg",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=earbuds+for+gaming&shoprs=CAEYASoHZWFyYnVkczIcCAESCkZvciBHYW1pbmcYAjoKCKmjPhCqoz4wA1iD6CBgAg"
#       },
#       {
#         "text": "Water-resistant",
#         "shoprs": "CAEYASoHZWFyYnVkczIhCAESD1dhdGVyLXJlc2lzdGFudDoMCPTwnwQQ2_ifBDADWIPoIGAC",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=water-resistant+earbuds&shoprs=CAEYASoHZWFyYnVkczIhCAESD1dhdGVyLXJlc2lzdGFudDoMCPTwnwQQ2_ifBDADWIPoIGAC"
#       },
#       {
#         "text": "With Adaptive EQ",
#         "shoprs": "CAEYASoHZWFyYnVkczIkCAESEFdpdGggQWRhcHRpdmUgRVEYAjoMCLDDsgIQscOyAjADWIPoIGAC",
#         "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=earbuds+with+adaptive+eq&shoprs=CAEYASoHZWFyYnVkczIkCAESEFdpdGggQWRhcHRpdmUgRVEYAjoMCLDDsgIQscOyAjADWIPoIGAC"
#       }
#     ],
#     "input_type": "checkbox"
#   },
#   {
#     "type": "Price",
#     "options": [
#       {
#         "text": "Under $25",
#         "shoprs": "CAESDRILEQAAAACE13dBGAEYBSoHZWFyYnVkczIiCAUSCVVuZGVyICQyNRgCIg0SCxEAAAAAhNd3QRgBKgIYAViD6CBgAg",
#         "serpapi_link": "https://serpapi.com/search.jso
#
#
#
#
#
# ======== search_metadata ========
# {
#   "id": "6935bb7a822c5fadb260cbf3",
#   "status": "Success",
#   "created_at": "2025-12-07 17:38:02 UTC",
#   "processed_at": "2025-12-07 17:38:02 UTC",
#   "json_endpoint": "https://serpapi.com/searches/820b49a296789661/6935bb7a822c5fadb260cbf3.json",
#   "raw_html_file": "https://serpapi.com/searches/820b49a296789661/6935bb7a822c5fadb260cbf3.html",
#   "total_time_taken": 1.64,
#   "google_shopping_url": "https://www.google.com/search?udm=28&q=earbuds&num=100&hl=en&gl=us"
# }
#
#
#
#
#
# ======== shopping_results ========
# [
#   {
#     "tag": "60% OFF",
#     "price": "$9.99",
#     "title": "JLab Go Air Pop True Wireless Earbuds",
#     "rating": 4.3,
#     "source": "Best Buy",
#     "reviews": 23000,
#     "snippet": "Good sound quality (5,773 user reviews)",
#     "delivery": "Free delivery on $35+",
#     "position": 1,
#     "old_price": "$25",
#     "thumbnail": "https://encrypted-tbn1.gstatic.com/shopping?q=tbn:ANd9GcTbNyV_AuElGHZNEoktnjkvxCZkIxJ59p1ZGD39g3NfQrSiYEbGhidfqgijG9H84IzGcFHqHahQSvcU_BVa_Np0JItBIsX8dQ",
#     "extensions": [
#       "60% OFF"
#     ],
#     "product_id": "8372463217625314514",
#     "source_icon": "https://serpapi.com/searches/6935bb7a822c5fadb260cbf3/images/3ecd3940cc0096e1c35619baf4a28f60ad9a3a0c3fdde93621dc965342e056e4.png",
#     "product_link": "https://www.google.com/search?ibp=oshop&q=earbuds&prds=catalogid:8372463217625314514,headlineOfferDocid:9532502713511546235,imageDocid:289739303464432744,rds:PC_9146411353573113826|PROD_PC_9146411353573113826,gpcid:9146411353573113826,pvt:hg&hl=en&gl=us&udm=28",
#     "extracted_price": 9.99,
#     "multiple_sources": true,
#     "serpapi_thumbnail": "https://serpapi.com/images/url/jBwIbHicDclRCoIwAADQE6WJBU6I0LJtfgzEkvJHdNNtWnPqkuwkXa3b1Pt9348wRk--bdeKjos2NVuZSjkWn0xpJLVo_7An0WstFd8Pu__5AWEA0nNFlqwIntEdopxEfWdU282vQ97hV7wF2snh0QXcJU0ypvIWVVBI1gxcthAgb4PfkJ7QgEqRpDO9FGFWFkSvY2xCPF09lvwAO_I24g",
#     "extracted_old_price": 25,
#     "immersive_product_page_token": "...",
#     "serpapi_immersive_product_api": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D"
#   },
#   {
#     "price": "$249.00",
#     "title": "Apple AirPods Pro 3",
#     "rating": 4.5,
#     "source": "Apple",
#     "reviews": 16000,
#     "snippet": "Good sound quality (1,111 user reviews)",
#     "delivery": "Free delivery",
#     "position": 2,
#     "thumbnail": "https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcTOd65Oi_kk6L8o6sY8ySLi1ra3RJ7CM0OAUdP98sKTy4AuJO-0zG8BYlLniNS1gOCQ45N4s9tEWeLFxJW1sU7xtUZcWNX6YFMbNAFWKYYlmhW_fWn7AwwhulU",
#     "product_id": "2327420681279440941",
#     "source_icon": "https://serpapi.com/searches/6935bb7a822c5fadb260cbf3/images/3ecd3940cc0096e1c35619baf4a28f60e713b4fc724cd79f1b02e7453cb551a9.png",
#     "product_link": "https://www.google.com/search?ibp=oshop&q=earbuds&prds=catalogid:2327420681279440941,headlineOfferDocid:11849172577489845529,imageDocid:18142110344459211046,rds:PC_3323897376901893063|PROD_PC_3323897376901893063,gpcid:3323897376901893063,mid:576462846061645004,pvt:hg&hl=en&gl=us&udm=28",
#     "extracted_price": 249.0,
#     "multiple_sources": true,
#     "serpapi_thumbnail": "https://serpapi.com/images/url/wmXnhXicDcnbCoIwAADQL0qzvAYRK1LwslUma72ITtOhTnOLsr_qc_qbOq_n-6mlHMRKVUtOx2mQZTGTOV8olZCZZFShfaeKuh8GxqvNff2_FYCF49EzKkwDsbRpzNDuTUHsKQ6ZNmbLk2_tojkCSXFwbBGcJx08fDSbvz17S9qQMxhrFdoddQPqwpF7XIbuy8eaSKyXTK4Uw4tJ3CiHwMUBIW1X4_SGuQWez_rRJj9QFz2f",
#     "immersive_product_page_token": "...",
#     "serpapi_immersive_product_api": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D"
#   },
#   {
#     "price": "$67.26",
#     "title": "JBL Tune Flex 2 Noise Cancelling True Wireless Earbuds",
#     "rating": 4.0,
#     "source": "Walmart",
#     "reviews": 875,
#     "snippet": "Good sound quality (140 user reviews)",
#     "delivery": "Free delivery",
#
#
#
#
#
#
# ======== search_parameters ========
# {
#   "q": "earbuds",
#   "gl": "us",
#   "hl": "en",
#   "num": "100",
#   "device": "desktop",
#   "engine": "google_shopping",
#   "google_domain": "google.com"
# }
#
#
#
#
#
# ======== search_information ========
# {
#   "query_displayed": "earbuds",
#   "shopping_results_state": "Results for exact spelling"
# }
#
#
#
#
#
# ======== serpapi_pagination ========
# {
#   "next": "https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&num=100&q=earbuds&start=10"
# }
#
#
#
#
#
# ======== categorized_shopping_results ========
# [
#   {
#     "title": "Wireless ANC earbuds",
#     "shopping_results": [
#       {
#         "tag": "47% OFF",
#         "price": "$41.99",
#         "title": "Soundcore P40i by Anker Noise Cancelling Wireless Earbuds",
#         "rating": 4.6,
#         "source": "soundcore US",
#         "reviews": 3900,
#         "delivery": "Free delivery",
#         "position": 1,
#         "old_price": "$80",
#         "thumbnail": "https://serpapi.com/searches/6935bb7a822c5fadb260cbf3/images/6e7143b25af17f7480359efafbf51757c42ca21189fe4bf04cb12e5ac9b3634adf2937fece328136356979aef6502fbea394547c9817d5889b922506d387850f.webp",
#         "extensions": [
#           "47% OFF"
#         ],
#         "product_id": "6111355610975527891",
#         "source_icon": "https://serpapi.com/searches/6935bb7a822c5fadb260cbf3/images/6e7143b25af17f7480359efafbf51757c42ca21189fe4bf04cb12e5ac9b3634adf2937fece328136356979aef6502fbeb96e4092d4d9e0f4d27b502763a6cacb.png",
#         "product_link": "https://www.google.com/search?ibp=oshop&q=earbuds&prds=catalogid:6111355610975527891,headlineOfferDocid:10318761261640458071,imageDocid:4709547386251943734,rds:PC_9640555644019820228|PROD_PC_9640555644019820228,gpcid:9640555644019820228,mid:576462851676467138,pvt:hg&hl=en&gl=us&udm=28",
#         "extracted_price": 41.99,
#         "multiple_sources": true,
#         "extracted_old_price": 80,
#         "immersive_product_page_token": "...",
#         "serpapi_immersive_product_api": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D%3D"
#       },
#       {
#         "tag": "27% OFF",
#         "price": "$129.00",
#         "title": "Bose QuietComfort Wireless Noise-Cancelling Earbuds",
#         "rating": 4.3,
#         "source": "Best Buy",
#         "reviews": 8000,
#         "delivery": "Free delivery by Tue",
#         "position": 2,
#         "old_price": "$179",
#         "thumbnail": "https://serpapi.com/searches/6935bb7a822c5fadb260cbf3/images/6e7143b25af17f7480359efafbf51757c42ca21189fe4bf04cb12e5ac9b3634adf2937fece328136356979aef6502fbe46cab484bb3eb9c5a6dca4385b2d2bc3.webp",
#         "extensions": [
#           "27% OFF"
#         ],
#         "product_id": "15437497629291295509",
#         "source_icon": "https://serpapi.com/searches/6935bb7a822c5fadb260cbf3/images/6e7143b25af17f7480359efafbf51757c42ca21189fe4bf04cb12e5ac9b3634adf2937fece328136356979aef6502fbe8a0cb3853e0aa9a56c9002fe8015002c.png",
#         "product_link": "https://www.google.com/search?ibp=oshop&q=earbuds&prds=catalogid:15437497629291295509,headlineOfferDocid:4302414039847788118,imageDocid:8550468907612115054,rds:PC_14541024020599492127|PROD_PC_14541024020599492127,gpcid:14541024020599492127,pvt:hg&hl=en&gl=us&udm=28",
#         "extracted_price": 129.0,
#         "multiple_sources": true,
#         "extracted_old_price": 179,
#         "immersive_product_page_token": "...",
#         "serpapi_immersive_product_api": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D%3D"
#       },
#       {
#         "tag": "30% OFF",
#         "price": "$69.99",
#         "title": "JLab Epic Sport ANC 3 True Wireless Earbuds",
#         "rating": 4.1,
#         "source": "JLab",
#         "reviews": 1200,
#         "delivery": "Free delivery by Thu",
#         "position": 3,
#         "old_price": "$100",

# %% [markdown]
# ## 5. Document Structure and Entities
# From inspecting the JSON payload, the response contains several top-level sections.
# Only some contain business-relevant data worth staging.
#
# ### Likely Irrelevant (meta / API mechanics)
# - `filters` – UI refinements unrelated to product data
# - `search_metadata` – timestamps, request IDs, URLs
# - `search_information` – echo of the query text
# - `serpapi_pagination` – next-page links
#
# ### Relevant Entities
# #### **1. Keyword Search**
#
# Represents a single keyword search event.
# Comes primarily from:
# - `search_parameters`
#
# Each raw row → one search event (one keyword, one page).
#
# #### **2. Product Results**
# Represents a product appearing in search results.
# Found in:
# - `shopping_results`
# - `categorized_shopping_results` (same structure but grouped into categories)
#
# These two lists can be unified into a single entity with a `category` field (`NULL` or `"general"` for uncategorized results).

# %% [markdown]
# ## 6. Determine Staging Tables
# Based on the entities:

# %% [markdown]
# ### 6.1 stg_searches
# One row per keyword search. \
# Fields sourced from `search_parameters` plus:
# - `raw_id` (FK to raw table)
# - `pulled_at`
# - `keyword`
# - `page`

# %% [markdown]
# ### 6.2 stg_results
# One row per product result.
#
# **Core fields:**
# - stg_result_id
# - tag
# - title
# - extracted_price & extracted_old_price
# - rating
# - reviews
# - source
# - multiple_sources
# - product_id
#
# **Module fields:**
# - module_type
# - module_label
# - module_index
# - position_in_module
#
# **Search context:**
# - raw_id
# - keyword
# - page
# - pulled_at
#
# This table will contain ~50-75 rows per SerpAPI pull request.

# %% [markdown]
# ## 7. Prototype `stg_searches` Flattening Logic
# The goal of this section is to prototype how raw search metadata from the SerpAPI
# response will be transformed into a clean `stg_searches` record.
#
# This table represents **one row per keyword search** and contains:
# - Identifiers linking back to `raw_google_shopping` (`raw_id`, `pulled_at`, `keyword`, `page`)
# - Search parameters extracted from the `"search_parameters"` object
# - Only values actually useful for analytics or debugging (e.g., device, number of results requested)
#
# Once validated here, this logic will later be moved into the proper staging notebook
# where it will run for **every raw record** during ingestion.

# %%
def build_searches_for_keyword():
    """
    Build the stg_searches record for a single raw search event.

    This function:
    - Takes the first row of df_raw (prototype mode)
    - Extracts identifiers (raw_id, pulled_at, keyword, page)
    - Extracts search parameters from response_json["search_parameters"]
    - Places everything into a clean, single-row DataFrame

    Returns:
        pd.DataFrame: one clean stg_search row
    """
    
     # Grab the first raw record (example row in this case)
    search_row = df_raw.loc[0, :]

     # Pull identifiers & search metadata from the raw table
    raw_id, pulled_at, keyword, page = search_row[['id', 'pulled_at', 'keyword', 'page']]
    
    # Extract the "search_parameters" object from the JSON
    params = search_row["response_json"]["search_parameters"]

    # Build the clean staging DataFrame
    search_df_clean = pd.DataFrame([{
    "raw_id": raw_id,
    "pulled_at": pulled_at,
    "keyword": keyword,
    "page": page,
    "gl": params.get("gl"),
    "hl": params.get("hl"),
    "device": params.get("device"),
    "num_results_requested": int(params.get("num")),
    "engine": params.get("engine"),
    "google_domain": params.get("google_domain"),
    }])
    return search_df_clean
    
build_searches_for_keyword()
# Out:
#    raw_id                        pulled_at               keyword  page  gl  \
# 0      28 2025-12-07 17:38:27.301076+00:00  bluetooth headphones     1  us
#
#    hl   device  num_results_requested           engine google_domain
# 0  en  desktop                    100  google_shopping    google.com

# %% [markdown]
# ## 8. Prototype stg_results Flattening Logic
#
# Goal: take a single raw SerpAPI response and turn all product rows
# (for that keyword+page) into a clean, tabular DataFrame that matches
# our upcoming `stg_results` schema.
#
# We do this in two layers:
#
# 1. **`transform_results_df`**
#    Takes a raw “results” DataFrame for one module (either 'All products'/uncategorized
#    or a specific category), drops/renames columns, normalizes types, and
#    adds module + search context fields.
#
# 2. **`build_results_for_keyword`**
#    For one raw row in `raycon.raw_google_shopping`:
#    - Flatten `shopping_results` into the “All products” category
#    - Run 'All products' piece through `transform_results_df`
#    - Flatten each entry in `categorized_shopping_results` into their respective categories
#    - Run each piece through `transform_results_df`
#    - Union 'All products' & the categorized results into one DataFrame: **one row per product result**.

# %%
def transform_results_df(
    df_in,
    *,
    raw_id,
    keyword,
    page,
    pulled_at,
    module_type,
    module_label,
    module_index):
    """
    Take a raw shopping-results DataFrame for a single module
    and return a cleaned, standardized results DataFrame.

    - Drops unused SerpAPI fields
    - Normalizes `multiple_sources` to boolean
    - Renames extracted price fields
    - Adds module + search context columns
    - Reorders columns to match `stg_results` schema
    """
    # Work on a copy to avoid mutating the original input
    transform_df = df_in.copy()

    # 1) Drop columns we decided not to stage
    transform_df = transform_df.drop(columns=['snippet', 'price', 'delivery', 'old_price', 'thumbnail',
                                             'extensions', 'source_icon', 'product_link', 'serpapi_thumbnail', 
                                            'immersive_product_page_token', 'serpapi_immersive_product_api'],
                                    errors='ignore')

    # 2) Convert multiple_sources -> proper bool
    transform_df['multiple_sources'] = (
        transform_df['multiple_sources'].replace('True', True).fillna(False).astype(bool)
   )

    # 3) Rename fields to final names
    transform_df = transform_df.rename(columns={
        'position': 'position_in_module',
        'extracted_price': 'price',
        'extracted_old_price': 'old_price'
    })

    # 4) Attach module + search context
    transform_df = transform_df.assign(
        module_type=module_type,
        module_label=module_label,
        module_index=module_index,
        raw_id=raw_id,
        keyword=keyword,
        page=page,
        pulled_at=pulled_at
    )

    # 5) Reorder columns to match target table
    final_cols = [
    "raw_id",
    "keyword",
    "page",
    "pulled_at",
    "title",
    "product_id",
    "price",
    "old_price",
    "reviews",
    "rating",
    "source",
    "multiple_sources",
    "tag",
    "module_type",
    "module_label",
    "module_index",
    "position_in_module",
    ]
    transform_df = transform_df.reindex(columns=final_cols)
    
    return transform_df

# %%
def build_results_for_keyword():
    """
    Build a full results DataFrame for ONE raw keyword request row.

    Steps:
    - Pull raw_id / keyword / page / pulled_at from df_raw
    - Flatten `shopping_results` (all products)
    - Flatten each entry in `categorized_shopping_results`
    - Run everything through `transform_results_df`
    - Union uncategorized + categorized into one DataFrame
    """
     # 1) Grab the first raw row (later this will be parameterized / looped)
    keyword_search = df_raw.loc[0, :]

     # 2) Extract search metadata used for context columns
    raw_id, pulled_at, keyword, page = keyword_search.loc[['id', 'pulled_at', 'keyword', 'page']]

    # 3) Extract JSON extract from the keyword request
    keyword_json = keyword_search.loc['response_json']

    # 4) Build uncategorized results
    uncategorized_df = pd.DataFrame(keyword_json['shopping_results'])
    uncategorized_df_clean = transform_results_df(uncategorized_df, 
                                                raw_id=raw_id, pulled_at=pulled_at, keyword=keyword, page=page,
                                                module_type='all_products', module_label='All products', module_index=99)

     # 5) Loop over categorized modules, flatten + transform each
    categorized_df_raw = pd.DataFrame(keyword_json['categorized_shopping_results'])
    for i in range(len(categorized_df_raw)):
        category_title = categorized_df_raw['title'][i]
        per_category_results_raw = pd.json_normalize(categorized_df_raw['shopping_results'][i])
        per_category_results_clean = transform_results_df(per_category_results_raw,
                                                         raw_id=raw_id, pulled_at=pulled_at, keyword=keyword, page=page,
                                                         module_type='categorized_products', module_label=categorized_df_raw['title'][i], module_index=i+1)
        if i == 0:
            categorized_df_clean = per_category_results_clean.copy()
        else:
            categorized_df_clean = (pd.concat([categorized_df_clean, per_category_results_clean], 
                                        ignore_index=True))

        # 6) Union uncategorized + categorized into one df
        keyword_search_df_clean = pd.concat([uncategorized_df_clean, categorized_df_clean], ignore_index=True)

    return keyword_search_df_clean
    
build_results_for_keyword().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   raw_id              65 non-null     int64
#  1   keyword             65 non-null     object
#  2   page                65 non-null     int64
#  3   pulled_at           65 non-null     datetime64[ns, UTC]
#  4   title               65 non-null     object
#  5   product_id          65 non-null     object
#  6   price               65 non-null     float64
#  7   old_price           47 non-null     float64
#  8   reviews             63 non-null     float64
#  9   rating              63 non-null     float64
#  10  source              65 non-null     object
#  11  multiple_sources    65 non-null     bool
#  12  tag                 47 non-null     object
#  13  module_type         65 non-null     object
#  14  module_label        65 non-null     object
#  15  module_index        65 non-null     int64
#  16  position_in_module  65 non-null     int64
# dtypes: bool(1), datetime64[ns, UTC](1), float64(4), int64(4), object(7)
# memory usage: 8.3+ KB

# %% [markdown]
# ## 8. Draft Staging Schema

# %% [markdown]
# ## 8. Draft Staging Schema
#
# The purpose of the staging layer (`stg_searches`, `stg_results`) is to
# standardize and clean the raw JSON into a relational, analysis-ready format.
#
# These tables:
# - Remove presentation-layer noise from the API (thumbnails, snippet text, etc.)
# - Normalize field names and data types
# - Preserve the original search context
# - Provide consistent module metadata for all result types
# - Act as the foundation for downstream marts and dashboards
#
# After prototyping the transformations above, the final schemas are:
#
# ---
#
# ### **8.1 `stg_searches` (one row per keyword search)**
#
# | Column | Type | Description |
# |--------|------|-------------|
# | `raw_id` | INT | Primary key from the raw table (links back to raw JSON) |
# | `pulled_at` | TIMESTAMP | When this keyword search was pulled |
# | `keyword` | TEXT | Search query term |
# | `page` | INT | Page number pulled (always 1 for now) |
# | `gl` | TEXT | Country parameter (e.g., `"us"`) |
# | `hl` | TEXT | Language parameter (e.g., `"en"`) |
# | `device` | TEXT | Device type used in the search (`"desktop"`) |
# | `num_results_requested` | INT | Requested SERP result count (e.g., 100) |
# | `engine` | TEXT | Search engine used (`"google_shopping"`) |
# | `google_domain` | TEXT | Google domain (`"google.com"`) |
#
# ---
#
# ### **8.2 `stg_results` (one row per product result)**
#
# | Column | Type | Description |
# |--------|------|-------------|
# | `raw_id` | INT | Foreign key to `stg_searches` (search context) |
# | `keyword` | TEXT | Keyword used for the search |
# | `page` | INT | Page number of the search |
# | `pulled_at` | TIMESTAMP | When the search was performed |
# | `title` | TEXT | Product title |
# | `product_id` | TEXT | SerpAPI product identifier |
# | `price` | FLOAT | Extracted numeric price |
# | `old_price` | FLOAT | Extracted numeric old price (if present) |
# | `reviews` | INT | Number of reviews |
# | `rating` | FLOAT | Star rating |
# | `source` | TEXT | Seller / retailer |
# | `multiple_sources` | BOOLEAN | Whether the product is offered by multiple sellers |
# | `tag` | TEXT | Discount / badge text (e.g., `"40% OFF"`) |
# | `module_type` | TEXT | Module category (`all_products`, `categorized_products`) |
# | `module_label` | TEXT | Module title (subcategory name) |
# | `module_index` | INT | Ordering of modules (99 = uncategorized, 0–4 for categories) |
# | `position_in_module` | INT | Position of the item inside its module |
#
# ---
#
# ### Notes
#
# - `stg_results` may contain roughly **50–75 rows per keyword search**.
# - `multiple_sources` is normalized to a boolean.
# - `module_type`, `module_label`, and `module_index` unify both uncategorized results and category-specific results.
# - These schemas match the output of the helper functions in Section 7 and will be used when writing the SQL `CREATE TABLE` scripts in the next notebook.

# %% [markdown]
# ## 9. Conclusion
#
# This notebook defined the staging layer structure and prototyped the transformations for `stg_searches` and `stg_results`.
#
# ### Next Steps
# 1. Write the SQL DDL script that creates both staging tables.
# 2. Build the production staging notebook to:
#    - Loop through all raw records that haven't yet been staged
#    - Apply the transformation functions
#    - Load data into staging tables
#
# These steps complete the transition from exploration to the development of the formal staging pipeline.
